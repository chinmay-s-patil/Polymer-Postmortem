# %%
import os
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import sklearn.model_selection

# %%
file1 = r"D:\For People\For Ashwath\Strain Data Missing Estimation\csvs\Tough1500\Tough1500_100um_noExt_BoldCobra_X01.csv"
file2 = r"D:\For People\For Ashwath\Strain Data Missing Estimation\csvs\Tough1500\Tough1500_HonestKraken_removeExtAt50pct_X01.csv"
file3 = r"D:\For People\For Ashwath\Strain Data Missing Estimation\csvs\Tough1500\Tough1500v2_printed-May-2025_1.csv"
